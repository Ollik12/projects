# %% [markdown]
# #   ROS2 | Exercise 4 - Computer Vision
#
# ##  Task 3 - Object Detection
#
# ### Pre-requisites
# Before you begin this Notebook you have to complete the following tasks explained in the handout
# - [x] Setting up the gazebo simulation as a ROS package
# - [x] Setting up Conda environment to run this jupyter notebook
#
# ### Introduction
# Object detection and its importance in robotics. Opencv Intro. Some images
#
# There are 3 parts in this Notebook which covers the following
#    - 3.1 : Basic Image processing and Opencv contour detection
#    - 3.2 : Object detection and Tracking with Video
#    - 3.3 : Object detection and Tracking with ROS2

# %% [markdown]
# ***
# ### 3.1 Basic Image processing with OpenCV
#
# ### 3.1.1
# Familiarize yourself with the basic functionalities available in openCV for basic image reading and visualization with this reference [link](https://docs.opencv.org/4.x/db/deb/tutorial_display_image.html). It has both C++ & Python code. We are following python in this notebook. Execute the following code that reads an image file and displays it in an opencv window.

# %%
import imutils
import cv2
import numpy as np

frame = cv2.imread('image.png')
cv2.imshow("Tracking",frame)
cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()

# %% [markdown]
# ### 3.1.2
#
# It is important to  pre-process raw input images in computer vision tasks such as object detection and tracking. OpenCV imgproc module contains several functionalities which are often used in image processing.
#
# Convertion between color spaces is necessary to generate image masks. Execute and observe the following code where you convert an image from RGB to HSV color space. The code generates a mask of the green color object.
#
# **Your task**
#
# - [ ] Change HSV values in order to generate masks of other objects.
#
# **References**
# - [Concept of HSL and HSV Color spaces](https://en.wikipedia.org/wiki/HSL_and_HSV)
# - [Opencv basic Image processing functionalities](https://docs.opencv.org/4.x/d7/da8/tutorial_table_of_content_imgproc.html)
# - [OpenCV RGB-HSV color converstions documentation](https://docs.opencv.org/3.4.6/de/d25/imgproc_color_conversions.html#color_convert_rgb_hsv)

# %%
# lower and upper boundaries for HSV thresholds
# green/yellow
Lower = (29, 86, 6)
Upper = (64, 255, 255)
# for blue 
#Lower = (94, 80, 2)
#Upper = (126, 255, 255)
# for red
#Lower = (0, 120, 70)
#Upper = (10, 255, 255)
# for cyan
#Lower = (85, 80, 80)
#Upper = (100, 255, 255)
# for magenta:
#Lower = (140, 50, 50)
#Upper = (170, 255, 255)

def prep(frame):
    frame = imutils.resize(frame, width=600)
    ## Todo 3.1.3 gaussian blur
    blurred = cv2.GaussianBlur(frame, (11,11),0)
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv,Lower,Upper)
    
    ## Todo 3.1.3 erosian and dialation lets add the element option as in example code
    element = cv2.getStructuringElement(cv2.MORPH_RECT, (11,11))
    # same size so (11,11). MORPH_RECT creates rectangular kernel.
    mask = cv2.erode(mask, element, iterations=1)
    mask = cv2.dilate(mask, element, iterations=1)
    return mask, frame

mask,frame = prep(frame)

cv2.imshow("Image",frame)
cv2.imshow("Masked Image",mask)
cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()

# %% [markdown]
# ### 3.1.3
#
# The above implementation provides a satisfactory result. However, when dealing with noisy images it is important to perform morphological transformations such as smoothing, erotion and dialation to get better results.
#
# **Your task**
#
# Read the following documentations and implement the following transformations inside the prep_frame() function above.
#
#
# - [ ] Apply Gaussian blur with a kernel size of 11x11
# - [ ] Apply erosion
# - [ ] Apply dialation
#
# **References**
#
# - [Smoothing Images with OpenCV](https://docs.opencv.org/4.5.2/d4/d13/tutorial_py_filtering.html)
# - [Perform Erosion and Dialation on the image mask using OpenCV](https://docs.opencv.org/3.4/db/df6/tutorial_erosion_dilatation.html)

# %% [markdown]
# ### 3.1.4
#
# Finding contours in an image is useful in object detection and tracking. The code snippet below extracts contours from the image file and draws a circle with its center as the same center of detected contour. Execute the code below and observe the results.
#
# **References**
# - [ Detecting contours with OpenCV](https://docs.opencv.org/4.5.0/d4/d73/tutorial_py_contours_begin.html)

# %%
### Find contours and display
def find_cnts(mask):
    cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    return cnts

cnts = find_cnts(mask)
c = max(cnts, key=cv2.contourArea)
((x, y), radius) = cv2.minEnclosingCircle(c) ## A different contour?
        
# Find center of contour using moments in opencvq
M = cv2.moments(c)
center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

#circle
frame1 = frame
cv2.circle(frame1, (int(x), int(y)), int(radius),(0, 0, 255), 2)
cv2.circle(frame1, center, 5, (0, 0, 255), -1)    
#cv2.imshow("Circle", frame1)


## ToDo 3.1.5 
#  1. Bounding rectancgle
# bonding rectangle where (x,y) is the top-left corner of the rectangle
frame_rect = frame
x_rect, y_rect, w_rect, h_rect = cv2.boundingRect(c)
cv2.rectangle(frame_rect, (x_rect, y_rect), (x_rect + w_rect, y_rect + h_rect), (0, 255, 0), 2)
#cv2.imshow("Rectangle + Circle", frame_rect)

# rotated rectangle:
frame_rot_rect = frame
rect = cv2.minAreaRect(c)
box = cv2.boxPoints(rect)
box = box.astype(np.intp)
cv2.drawContours(frame_rot_rect,[box], 0,(255,0,0),2)
#cv2.imshow("rotated rectangle + rectangle + circle", frame_rot_rect)


#  2. Convex Hull
frame4_hull = frame
hull = cv2.convexHull(c)
cv2.drawContours(frame4_hull, [hull], 0, (255,255,0), 2)
cv2.imshow("rotated rectangle + rectangle + circle + hull", frame)

cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()

# %% [markdown]
# ### 3.1.5
# The above implementation only uses a minimum enclosing circle for labelling the detected image. There are more labelling options such as bounding boxes and convex hull which may come handy in various computer vision tasks.
#
# **Your task**
#
# - [ ] Implement a bounding rectangle and rotated rectangle on the detected contours by modifying the code in 3.1.4
# - [ ] Implement a convex hull on the detected contours by modifying the code in 3.1.4
#
# **References**
# - [Contour features in OpenCV](https://docs.opencv.org/4.x/dd/d49/tutorial_py_contour_features.html)
# - [Creating Bounding boxes and circles for contours](https://docs.opencv.org/4.x/da/d0c/tutorial_bounding_rects_circles.html)
# -[Convex Hull](https://docs.opencv.org/4.x/d7/d1d/tutorial_hull.html)

# %% [markdown]
# ***
# ### 3.2 Object detection and Tracking with Video
#
# ### 3.2.1
#
# Execute and observe the below code snippet which reads frames from a given video file at a pre-defined frame rate.
#
# **Your task**
# - [ ] Implement pre-processing and find contour of the moving blob on by modifiying the same code below
# - [ ] Implement a suitable labelling mode (Enclosed Circle / bounding Box or convex hull) and display the resulted tracking on a seperated window
#
# **Tip** : Use the same functions from 3.1. Avoid creating duplicate functions and unnecessarily lenghty code

# %%
from imutils.video import VideoStream
import time

vs = cv2.VideoCapture("test_video.avi")
time.sleep(2.0)

frame_rate = 30
prev = 0
# lets read one frame as the reference
ret, prev_frame = vs.read()
prev_frame = prev_frame if ret else None
# then turning into hsv colors and adding blur
hsv = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
hsv = cv2.GaussianBlur(hsv, (11,11), 0)

while True :
    time_elapsed = time.time() - prev
    
    # additionally add a box for current frame always! - convex hull.
    if time_elapsed > 1./frame_rate:
        # here a new frame is grabbed so lets blur it and convert to grayscale.
        # and then compute the difference.
        frame = vs.read()
        frame = frame[1]
        if frame is None:
            break
            
        hsv_cur = cv2.GaussianBlur(frame, (11,11), 0)
        hsv_cur = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        difference = cv2.absdiff(hsv_cur, hsv)
        # and displaying the gray image.
        cv2.imshow("Difference frame", difference)
        cv2.imshow("Frame", frame)
        key = cv2.waitKey(1) & 0xFF
        if key == ord("q"):
            break
        prev = time.time()
        # and finally updating the last frame to be the current one:
        hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        hsv = cv2.GaussianBlur(hsv, (11,11), 0)
        
        # Define blue color range in HSV
        lower_blue = np.array([90, 100, 50])
        upper_blue = np.array([130, 255, 255])
        # Create mask for blue regions and clean up and make rgb picture for colors.
        hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
        mask = cv2.inRange(hsv_frame, lower_blue, upper_blue)
        mask = cv2.erode(mask, None, iterations=2)
        mask = cv2.dilate(mask, None, iterations=2)
        # from 3.1 using the circular
        
        cnts = find_cnts(mask)
        if len(cnts) > 0: # this so no crash
            c = max(cnts, key=cv2.contourArea)
            ((x, y), radius) = cv2.minEnclosingCircle(c) ## A different contour?
                    
            # Find center of contour using moments in opencvq
            M = cv2.moments(c)
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))
            
            #circle
            frame1 = frame
            cv2.circle(frame1, (int(x), int(y)), int(radius),(0, 0, 255), 2)
            cv2.circle(frame1, center, 5, (0, 0, 255), -1)
            cv2.imshow("Circle", frame1)
        
            
cv2.destroyAllWindows()

# %% [markdown]
# ---
#
# ###  3.3 Object detection and Tracking with ROS2
#
# ### 3.3.1
#
# In applications concerning robotic perception, so often visual data are obtained via camera sensors interfaced with ros. In this section you are provided with a ros-ignition simulation package which publish camera sensor data. The code snippet below subscribes to the camera sensor data and stream on to an OpenCV window.
#
# Assuming you have successfully build the package on your system using the instructions from handout, Open a New shell in you terminal and launch the simulation.
#
# ```
# $ source /opt/ros/foxy/setup.bash
# $ cd ~/ws
# $ source install/setup.bash
# $ ros2 launch walking_actor cam_world.launch.py
# ```
#
# While the simulation is running in background , run the code snippet below and observe the result
#
# - To close the cv2 window , select the window and press 'q'
# - To stop the execution of code snippet, double press on 'i' in keyboard or interrupt the kernel from menu
#
#
# **Your task**
#
# - [ ] Modify the python code to track the walking actor. You can use any feature of the actor to track.
# - [ ] Display the tracking in a seperate cv2 window
#
#
# **References**
# - [ROS2 python subscriber/publisher](https://docs.ros.org/en/foxy/Tutorials/Beginner-Client-Libraries/Writing-A-Simple-Py-Publisher-And-Subscriber.html)
# - [rclpy API Documentation](https://docs.ros2.org/foxy/api/rclpy/api/execution_and_callbacks.html#module-rclpy.executors)

# %%
import sys
import rclpy
from rclpy.node import Node
from cv_bridge import CvBridge
import numpy as np
import cv2
from sensor_msgs.msg import Image, CameraInfo
#print(sys.path)

bridge = CvBridge()

class Get_Images(Node):

    def __init__(self):
        # Initialize the node
        super().__init__('Image_Subscriber')
        # Initialize the subscriber
        self.subscription_ = self.create_subscription( Image,'/camera', self.listener_callback,10)
        self.subscription_  # prevent unused variable warning
        timer_period = 0.1  # seconds
        self.timer = self.create_timer(timer_period, self.timer_callback)
        self.K = True
        self.prev_available = False
        self.previous = None

    def listener_callback(self, msg):
        height = msg.height
        width = msg.width
        channel = msg.step//msg.width
        #frame = np.reshape(msg.data, (height, width, channel))
        self.frame =  bridge.imgmsg_to_cv2(msg, desired_encoding='bgr8')
        self.get_logger().info("Image Received")
        return self.frame
    
    def timer_callback(self):
        if self.K == True:
            # implement the grey difference here aswell!
            # logic of comparing the previous one with the current
            # some logic to check if prev_available = true then we can check
            if self.prev_available == True:
                # take the previous frame
                # compare hsv pics
                hsv_cur = cv2.cvtColor(self.frame, cv2.COLOR_BGR2GRAY)
                hsv_cur = cv2.GaussianBlur(hsv_cur, (11,11), 0)
                hsv_prev = cv2.cvtColor(self.previous, cv2.COLOR_BGR2GRAY)
                hsv_prev = cv2.GaussianBlur(hsv_prev, (11,11), 0)
                difference = cv2.absdiff(hsv_cur, hsv_prev)
                
                # Adding the tracking into the difference so it is tracked
                empty, mask = cv2.threshold(difference, 25, 255, cv2.THRESH_BINARY)
                mask = cv2.dilate(mask, None, iterations=2)
                cnts = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
                cnts = imutils.grab_contours(cnts)
                if len(cnts) > 0:
                    c = max(cnts, key=cv2.contourArea)
                    x, y, w, h = cv2.boundingRect(c)
                # convert to rgb
                display_frame = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
                cv2.rectangle(display_frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
                cv2.imshow("Motion Tracking with Box", display_frame)
                
            cv2.imshow("Tracking",self.frame)
            key = cv2.waitKey(1) & 0xFF
            if key == ord("q"):
                self.get_logger().info('Closing stream window..')
                self.K = False
                cv2.destroyAllWindows()

            # update the previous to be the current
            self.prev_available = True
            self.previous = self.frame
                
    def stop_stream(self):
        self.get_logger().info('Stopping the stream ...')
        

try:
    # adding this works just fine so no overlapping instances.
    if not rclpy.ok():
        rclpy.init(args=None)
    image_subscriber = Get_Images()
    rclpy.spin(image_subscriber)

except KeyboardInterrupt:
    # executes on keyboard kernal interrupt with double pressing button "i"
    image_subscriber.stop_stream()
    image_subscriber.destroy_node()
    rclpy.shutdown()
# Out:
# [INFO] [1760688288.572165179] [Image_Subscriber]: Image Received
# [INFO] [1760688288.616308712] [Image_Subscriber]: Image Received
# [INFO] [1760688288.639151670] [Image_Subscriber]: Image Received
# [INFO] [1760688288.712107839] [Image_Subscriber]: Image Received
# [INFO] [1760688288.741075432] [Image_Subscriber]: Image Received
# [INFO] [1760688288.811187863] [Image_Subscriber]: Image Received
# [INFO] [1760688288.845302183] [Image_Subscriber]: Image Received
# [INFO] [1760688288.900155214] [Image_Subscriber]: Image Received
# [INFO] [1760688288.940413964] [Image_Subscriber]: Image Received
# [INFO] [1760688289.072496206] [Image_Subscriber]: Image Received
# [INFO] [1760688289.176080988] [Image_Subscriber]: Image Received
# [INFO] [1760688289.256643288] [Image_Subscriber]: Image Received
# [INFO] [1760688289.335565181] [Image_Subscriber]: Image Received
# [INFO] [1760688289.395398234] [Image_Subscriber]: Image Received
# [INFO] [1760688289.423535989] [Image_Subscriber]: Image Received
# [INFO] [1760688289.449264124] [Image_Subscriber]: Image Received
# [INFO] [1760688289.495642364] [Image_Subscriber]: Image Received
# [INFO] [1760688289.518127640] [Image_Subscriber]: Image Received
# [INFO] [1760688289.534442443] [Image_Subscriber]: Image Received
# [INFO] [1760688289.590725324] [Image_Subscriber]: Image Received
# [INFO] [1760688289.617461741] [Image_Subscriber]: Image Received
# [INFO] [1760688289.643365159] [Image_Subscriber]: Image Received
# [INFO] [1760688289.691248299] [Image_Subscriber]: Image Received
# [INFO] [1760688289.717265456] [Image_Subscriber]: Image Received
# [INFO] [1760688289.727895097] [Image_Subscriber]: Image Received
# [INFO] [1760688289.772578249] [Image_Subscriber]: Image Received
# [INFO] [1760688289.797629385] [Image_Subscriber]: Image Received
# [INFO] [1760688289.823614829] [Image_Subscriber]: Image Received
# [INFO] [1760688289.841650293] [Image_Subscriber]: Image Received
# [INFO] [1760688289.916655573] [Image_Subscriber]: Image Received
# [INFO] [1760688289.933213823] [Image_Subscriber]: Image Received
# [INFO] [1760688290.001478260] [Image_Subscriber]: Image Received
# [INFO] [1760688290.026653882] [Image_Subscriber]: Image Received
# [INFO] [1760688290.053776424] [Image_Subscriber]: Image Received
# [INFO] [1760688290.135949253] [Image_Subscriber]: Image Received
# [INFO] [1760688290.232663280] [Image_Subscriber]: Image Received
# [INFO] [1760688290.304102620] [Image_Subscriber]: Image Received
# [INFO] [1760688290.329159313] [Image_Subscriber]: Image Received
# [INFO] [1760688290.390035547] [Image_Subscriber]: Image Received
# [INFO] [1760688290.412045213] [Image_Subscriber]: Image Received
# [INFO] [1760688290.427217714] [Image_Subscriber]: Image Received
# [INFO] [1760688290.471326655] [Image_Subscriber]: Image Received
# [INFO] [1760688290.496976939] [Image_Subscriber]: Image Received
# [INFO] [1760688290.522761317] [Image_Subscriber]: Image Received
# [INFO] [1760688290.537952619] [Image_Subscriber]: Image Received
# [INFO] [1760688290.604614132] [Image_Subscriber]: Image Received
# [INFO] [1760688290.623098222] [Image_Subscriber]: Image Received
# [INFO] [1760688290.648104060] [Image_Subscriber]: Image Received
# [INFO] [1760688290.698796833] [Image_Subscriber]: Image Received
# [INFO] [1760688290.723177437] [Image_Subscriber]: Image Received
# [INFO] [1760688290.751421822] [Image_Subscriber]: Image Received
# [INFO] [1760688290.808800808] [Image_Subscriber]: Image Received
# [INFO] [1760688290.835187401] [Image_Subscriber]: Image Received
# [INFO] [1760688290.886364602] [Image_Subscriber]: Image Received
# [INFO] [1760688290.911957520] [Image_Subscriber]: Image Received
# [INFO] [1760688290.924784215] [Image_Subscriber]: Image Received
# [INFO] [1760688290.953322240] [Image_Subscriber]: Image Received
# [INFO] [1760688291.006124152] [Image_Subscriber]: Image Received
# [INFO] [1760688291.032243677] [Image_Subscriber]: Image Received
# [INFO] [1760688291.081109151] [Image_Subscriber]: Image Received
# [INFO] [1760688291.104178539] [Image_Subscriber]: Image Received
# [INFO] [1760688291.144443101] [Image_Subscriber]: Image Received
# [INFO] [1760688291.229646614] [Image_Subscriber]: Image Received
# [INFO] [1760688291.286260105] [Image_Subscriber]: Image Received
# [INFO] [1760688291.311263235] [Image_Subscriber]: Image Received
# [INFO] [1760688291.322102016] [Image_Subscriber]: Image Received
# [INFO] [1760688291.346072811] [Image_Subscriber]: Image Received
# [INFO] [1760688291.394358265] [Image_Subscriber]: Image Received
# [INFO] [1760688291.418840274] [Image_Subscriber]: Image Received
# [INFO] [1760688291.431441220] [Image_Subscriber]: Image Received
# [INFO] [1760688291.493366897] [Image_Subscriber]: Image Received
# [INFO] [1760688291.512123940] [Image_Subscriber]: Image Received
# [INFO] [1760688291.537017867] [Image_Subscriber]: Image Received
# [INFO] [1760688291.582027778] [Image_Subscriber]: Image Received
# [INFO] [1760688291.606482802] [Image_Subscriber]: Image Received
# [INFO] [1760688291.629179327] [Image_Subscriber]: Image Received
# [INFO] [1760688291.677073097] [Image_Subscriber]: Image Received
# [INFO] [1760688291.688246368] [Image_Subscriber]: Image Received
# [INFO] [1760688291.712406018] [Image_Subscriber]: Image Received
# [INFO] [1760688291.739506513] [Image_Subscriber]: Image Received
# [INFO] [1760688291.795693270] [Image_Subscriber]: Image Received
# [INFO] [1760688291.821101707] [Image_Subscriber]: Image Received
# [INFO] [1760688291.832841564] [Image_Subscriber]: Image Received
# [INFO] [1760688291.885364649] [Image_Subscriber]: Image Received
# [INFO] [1760688291.911449126] [Image_Subscriber]: Image Received
# [INFO] [1760688291.937820612] [Image_Subscriber]: Image Received
# [INFO] [1760688291.991665747] [Image_Subscriber]: Image Received
# [INFO] [1760688292.021489581] [Image_Subscriber]: Image Received
# [INFO] [1760688292.046547518] [Image_Subscriber]: Image Received
# [INFO] [1760688292.094680545] [Image_Subscriber]: Image Received
# [INFO] [1760688292.124941574] [Image_Subscriber]: Image Received
# [INFO] [1760688292.161348571] [Image_Subscriber]: Image Received
# [INFO] [1760688292.248551498] [Image_Subscriber]: Image Received
# [INFO] [1760688292.306711505] [Image_Subscriber]: Image Received
# [INFO] [1760688292.331505130] [Image_Subscriber]: Image Received
# [INFO] [1760688292.383664912] [Image_Subscriber]: Image Received
# [INFO] [1760688292.413997309] [Image_Subscriber]: Image Received
# [INFO] [1760688292.440103519] [Image_Subscriber]: Image Received
# [INFO] [1760688292.489426367] [Image_Subscriber]: Image Received
# [INFO] [1760688292.512797062] [Image_Subscriber]: Image Received
# [INFO] [1760688292.526051589] [Image_Subscriber]: Image Received
# [INFO] [1760688292.549920918] [Image_Subscriber]: Image Received
# [INFO] [1760688292.600800278] [Image_Subscriber]: Image Received
# [INFO] [1760688292.629921671] [Image_Subscriber]: Image Received
# [INFO] [1760688292.698562375] [Image_Subscriber]: Image Received
# [INFO] [1760688292.724214385] [Image_Subscriber]: Image Received
# [INFO] [1760688292.755404788] [Image_Subscriber]: Image Received
# [INFO] [1760688292.799240769] [Image_Subscriber]: Image Received
# [INFO] [1760688292.829186581] [Image_Subscriber]: Image Received
# [INFO] [1760688292.894575677] [Image_Subscriber]: Image Received
# [INFO] [1760688292.921178067] [Image_Subscriber]: Image Received
# [INFO] [1760688292.945232525] [Image_Subscriber]: Image Received
# [INFO] [1760688292.991705346] [Image_Subscriber]: Image Received
# [INFO] [1760688293.017490392] [Image_Subscriber]: Image Received
# [INFO] [1760688293.032087073] [Image_Subscriber]: Image Received
# [INFO] [1760688293.097201970] [Image_Subscriber]: Image Received
# [INFO] [1760688293.108879466] [Image_Subscriber]: Image Received
# [INFO] [1760688293.145433749] [Image_Subscriber]: Image Received
# [INFO] [1760688293.223183684] [Image_Subscriber]: Image Received
# [INFO] [1760688293.250140704] [Image_Subscriber]: Image Received
# [INFO] [1760688293.316499032] [Image_Subscriber]: Image Received
# [INFO] [1760688293.340038832] [Image_Subscriber]: Image Received
# [INFO] [1760688293.389128056] [Image_Subscriber]: Image Received
# [INFO] [1760688293.413246705] [Image_Subscriber]: Image Received
# [INFO] [1760688293.425122011] [Image_Subscriber]: Image Received
# [INFO] [1760688293.450224296] [Image_Subscriber]: Image Received
# [INFO] [1760688293.512746774] [Image_Subscriber]: Image Received
# [INFO] [1760688293.542279866] [Image_Subscriber]: Image Received
# [INFO] [1760688293.587432982] [Image_Subscriber]: Image Received
# [INFO] [1760688293.611635391] [Image_Subscriber]: Image Received
# [INFO] [1760688293.631842903] [Image_Subscriber]: Image Received
# [INFO] [1760688293.691032132] [Image_Subscriber]: Image Received
# [INFO] [1760688293.720523073] [Image_Subscriber]: Image Received
# [INFO] [1760688293.733761160] [Image_Subscriber]: Image Received
# [INFO] [1760688293.777177659] [Image_Subscriber]: Image Received
# [INFO] [1760688293.801581496] [Image_Subscriber]: Image Received
# [INFO] [1760688293.823091058] [Image_Subscriber]: Image Received
# [INFO] [1760688293.837345706] [Image_Subscriber]: Image Received
# [INFO] [1760688293.888241234] [Image_Subscriber]: Image Received
# [INFO] [1760688293.925689453] [Image_Subscriber]: Image Received
# [INFO] [1760688293.992700614] [Image_Subscriber]: Image Received
# [INFO] [1760688294.016977870] [Image_Subscriber]: Image Received
# [INFO] [1760688294.028284870] [Image_Subscriber]: Image Received
# [INFO] [1760688294.090953095] [Image_Subscriber]: Image Received
# [INFO] [1760688294.100858487] [Image_Subscriber]: Image Received
# [INFO] [1760688294.135067761] [Image_Subscriber]: Image Received
# [INFO] [1760688294.236151425] [Image_Subscriber]: Image Received
# [INFO] [1760688294.286709765] [Image_Subscriber]: Image Received
# [INFO] [1760688294.311626152] [Image_Subscriber]: Image Received
# [INFO] [1760688294.341086931] [Image_Subscriber]: Image Received
# [INFO] [1760688294.398274876] [Image_Subscriber]: Image Received
# [INFO] [1760688294.424567719] [Image_Subscriber]: Image Received
# [INFO] [1760688294.449577062] [Image_Subscriber]: Image Received
# [INFO] [1760688294.503761135] [Image_Subscriber]: Image Received
# [INFO] [1760688294.527994638] [Image_Subscriber]: Image Received
# [INFO] [1760688294.575660443] [Image_Subscriber]: Image Received
# [INFO] [1760688294.601970114] [Image_Subscriber]: Image Received
# [INFO] [1760688294.614256264] [Image_Subscriber]: Image Received
# [INFO] [1760688294.689661174] [Image_Subscriber]: Image Received
# [INFO] [1760688294.715597680] [Image_Subscriber]: Image Received
# [INFO] [1760688294.728587109] [Image_Subscriber]: Image Received
# [INFO] [1760688294.788258183] [Image_Subscriber]: Image Received
# [INFO] [1760688294.825211173] [Image_Subscriber]: Image Received
# [INFO] [1760688294.843747763] [Image_Subscriber]: Image Received
# [INFO] [1760688294.907402811] [Image_Subscriber]: Image Received
# [INFO] [1760688294.939080324] [Image_Subscriber]: Image Received
# [INFO] [1760688294.987058371] [Image_Subscriber]: Image Received
# [INFO] [1760688295.008476348] [Image_Subscriber]: Image Received
# [INFO] [1760688295.023584956] [Image_Subscriber]: Image Received
# [INFO] [1760688295.095643583] [Image_Subscriber]: Image Received
# [INFO] [1760688295.128628478] [Image_Subscriber]: Image Received
# [INFO] [1760688295.202426721] [Image_Subscriber]: Image Received
# [INFO] [1760688295.232537147] [Image_Subscriber]: Image Received
# [INFO] [1760688295.296862460] [Image_Subscriber]: Image Received
# [INFO] [1760688295.329192398] [Image_Subscriber]: Image Received
# [INFO] [1760688295.400020352] [Image_Subscriber]: Image Received
# [INFO] [1760688295.419761695] [Image_Subscriber]: Image Received
# [INFO] [1760688295.439549497] [Image_Subscriber]: Image Received
# [INFO] [1760688295.485311451] [Image_Subscriber]: Image Received
# [INFO] [1760688295.510894949] [Image_Subscriber]: Image Received
# [INFO] [1760688295.536676298] [Image_Subscriber]: Image Received
# [INFO] [1760688295.595800492] [Image_Subscriber]: Image Received
# [INFO] [1760688295.621288810] [Image_Subscriber]: Image Received
# [INFO] [1760688295.633302299] [Image_Subscriber]: Image Received
# [INFO] [1760688295.696846293] [Image_Subscriber]: Image Received
# [INFO] [1760688295.708366415] [Image_Subscriber]: Image Received
# [INFO] [1760688295.740268464] [Image_Subscriber]: Image Received
# [INFO] [1760688295.812539758] [Image_Subscriber]: Image Received
# [INFO] [1760688295.846212646] [Image_Subscriber]: Image Received
# [INFO] [1760688295.896713595] [Image_Subscriber]: Image Received
# [INFO] [1760688295.923815928] [Image_Subscriber]: Image Received
# [INFO] [1760688295.935540864] [Image_Subscriber]: Image Received
# [INFO] [1760688295.979568040] [Image_Subscriber]: Image Received
# [INFO] [1760688296.010956942] [Image_Subscriber]: Image Received
# [INFO] [1760688296.039596087] [Image_Subscriber]: Image Received
# [INFO] [1760688296.083013295] [Image_Subscriber]: Image Received
# [INFO] [1760688296.112252637] [Image_Subscriber]: Image Received
# [INFO] [1760688296.203348761] [Image_Subscriber]: Image Received
# [INFO] [1760688296.247643431] [Image_Subscriber]: Image Received
# [INFO] [1760688296.290351519] [Image_Subscriber]: Image Received
# [INFO] [1760688296.317802461] [Image_Subscriber]: Image Received
# [INFO] [1760688296.343562306] [Image_Subscriber]: Image Received
# [INFO] [1760688296.391236425] [Image_Subscriber]: Image Received
# [INFO] [1760688296.411690829] [Image_Subscriber]: Image Received
# [INFO] [1760688296.429606645] [Image_Subscriber]: Image Received
# [INFO] [1760688296.499193996] [Image_Subscriber]: Image Received
# [INFO] [1760688296.511495964] [Image_Subscriber]: Image Received
# [INFO] [1760688296.576890982] [Image_Subscriber]: Image Received
# [INFO] [1760688296.597983257] [Image_Subscriber]: Image Received
# [INFO] [1760688296.613448421] [Image_Subscriber]: Image Received
# [INFO] [1760688296.687224489] [Image_Subscriber]: Image Received
# [INFO] [1760688296.723575783] [Image_Subscriber]: Image Received
# [INFO] [1760688296.746324066] [Image_Subscriber]: Image Received
# [INFO] [1760688296.797771805] [Image_Subscriber]: Image Received
# [INFO] [1760688296.823444574] [Image_Subscriber]: Image Received
# [INFO] [1760688296.836623604] [Image_Subscriber]: Image Received
# [INFO] [1760688296.881645513] [Image_Subscriber]: Image Received
# [INFO] [1760688296.921956520] [Image_Subscriber]: Image Received
# [INFO] [1760688296.990736045] [Image_Subscriber]: Image Received
# [INFO] [1760688297.017057402] [Image_Subscriber]: Image Received
# [INFO] [1760688297.030259175] [Image_Subscriber]: Image Received
# [INFO] [1760688297.075041807] [Image_Subscriber]: Image Received
# [INFO] [1760688297.103109989] [Image_Subscriber]: Image Received
# [INFO] [1760688297.136642524] [Image_Subscriber]: Image Received
# [INFO] [1760688297.203394989] [Image_Subscriber]: Image Received
# [INFO] [1760688297.299356521] [Image_Subscriber]: Image Received
# [INFO] [1760688297.326099738] [Image_Subscriber]: Image Received
# [INFO] [1760688297.401848427] [Image_Subscriber]: Image Received
# [INFO] [1760688297.427585395] [Image_Subscriber]: Image Received
# [INFO] [1760688297.487078543] [Image_Subscriber]: Image Received
# [INFO] [1760688297.514737417] [Image_Subscriber]: Image Received
# [INFO] [1760688297.541828979] [Image_Subscriber]: Image Received
# [INFO] [1760688297.596374030] [Image_Subscriber]: Image Received
# [INFO] [1760688297.625606677] [Image_Subscriber]: Image Received
# [INFO] [1760688297.648281624] [Image_Subscriber]: Image Received
# [INFO] [1760688297.723091336] [Image_Subscriber]: Image Received
# [INFO] [1760688297.750560372] [Image_Subscriber]: Image Received
# [INFO] [1760688297.818019904] [Image_Subscriber]: Image Received
# [INFO] [1760688297.833735979] [Image_Subscriber]: Image Received
# [INFO] [1760688297.907096178] [Image_Subscriber]: Image Received
# [INFO] [1760688297.937821350] [Image_Subscriber]: Image Received
# [INFO] [1760688297.998368377] [Image_Subscriber]: Image Received
# [INFO] [1760688298.025480392] [Image_Subscriber]: Image Received
# [INFO] [1760688298.053045932] [Image_Subscriber]: Image Received
# [INFO] [1760688298.115043978] [Image_Subscriber]: Image Received
# [INFO] [1760688298.146138666] [Image_Subscriber]: Image Received
# [INFO] [1760688298.230512203] [Image_Subscriber]: Image Received
# [INFO] [1760688298.329599529] [Image_Subscriber]: Image Received
# [INFO] [1760688298.382864092] [Image_Subscriber]: Image Received
# [INFO] [1760688298.410218497] [Image_Subscriber]: Image Received
# [INFO] [1760688298.435501883] [Image_Subscriber]: Image Received
# [INFO] [1760688298.491555042] [Image_Subscriber]: Image Received
# [INFO] [1760688298.518909587] [Image_Subscriber]: Image Received
# [INFO] [1760688298.531549562] [Image_Subscriber]: Image Received
# [INFO] [1760688298.607735894] [Image_Subscriber]: Image Received
# [INFO] [1760688298.623470258] [Image_Subscriber]: Image Received
# [INFO] [1760688298.653128894] [Image_Subscriber]: Image Received
# [INFO] [1760688298.718771292] [Image_Subscriber]: Image Received
# [INFO] [1760688298.740243455] [Image_Subscriber]: Image Received
# [INFO] [1760688298.810878431] [Image_Subscriber]: Image Received
# [INFO] [1760688298.839471928] [Image_Subscriber]: Image Received
# [INFO] [1760688298.899405175] [Image_Subscriber]: Image Received
# [INFO] [1760688298.929291884] [Image_Subscriber]: Image Received
# [INFO] [1760688298.990527990] [Image_Subscriber]: Image Received
# [INFO] [1760688299.023893029] [Image_Subscriber]: Image Received
# [INFO] [1760688299.051862699] [Image_Subscriber]: Image Received
# [INFO] [1760688299.112354293] [Image_Subscriber]: Image Received
# [INFO] [1760688299.136012485] [Image_Subscriber]: Image Received
# [INFO] [1760688299.219424100] [Image_Subscriber]: Image Received
# [INFO] [1760688299.267125842] [Image_Subscriber]: Image Received
# [INFO] [1760688299.333556149] [Image_Subscriber]: Image Received
# [INFO] [1760688299.367540131] [Image_Subscriber]: Image Received
# [INFO] [1760688299.392033938] [Image_Subscriber]: Image Received
# [INFO] [1760688299.418507924] [Image_Subscriber]: Image Received
# [INFO] [1760688299.431596367] [Image_Subscriber]: Image Received
# [INFO] [1760688299.494458305] [Image_Subscriber]: Image Received
# [INFO] [1760688299.521611102] [Image_Subscriber]: Image Received
# [INFO] [1760688299.546893365] [Image_Subscriber]: Image Received
# [INFO] [1760688299.596510397] [Image_Subscriber]: Image Received
# [INFO] [1760688299.621860904] [Image_Subscriber]: Image Received
# [INFO] [1760688299.635101243] [Image_Subscriber]: Image Received
# [INFO] [1760688299.677768581] [Image_Subscriber]: Image Received
# [INFO] [1760688299.707715516] [Image_Subscriber]: Image Received
# [INFO] [1760688299.734894367] [Image_Subscriber]: Image Received
# [INFO] [1760688299.783288944] [Image_Subscriber]: Image Received
# [INFO] [1760688299.807944643] [Image_Subscriber]: Image Received
# [INFO] [1760688299.820066631] [Image_Subscriber]: Image Received
# [INFO] [1760688299.842770118] [Image_Subscriber]: Image Received
# [INFO] [1760688299.897182783] [Image_Subscriber]: Image Received
# [INFO] [1760688299.924358618] [Image_Subscriber]: Image Received
# [INFO] [1760688299.947098727] [Image_Subscriber]: Image Received
# [INFO] [1760688300.005283938] [Image_Subscriber]: Image Received
# [INFO] [1760688300.034073949] [Image_Subscriber]: Image Received
# [INFO] [1760688300.091779362] [Image_Subscriber]: Image Received
# [INFO] [1760688300.123037785] [Image_Subscriber]: Image Received
# [INFO] [1760688300.148574303] [Image_Subscriber]: Image Received
# [INFO] [1760688300.211293871] [Image_Subscriber]: Image Received
# [INFO] [1760688300.247806904] [Image_Subscriber]: Image Received
# [INFO] [1760688300.318830320] [Image_Subscriber]: Image Received
# [INFO] [1760688300.346483839] [Image_Subscriber]: Image Received
# [INFO] [1760688300.402644984] [Image_Subscriber]: Image Received
# [INFO] [1760688300.429242146] [Image_Subscriber]: Image Received
# [INFO] [1760688300.475905524] [Image_Subscriber]: Image Received
# [INFO] [1760688300.501332277] [Image_Subscriber]: Image Received
# [INFO] [1760688300.511746316] [Image_Subscriber]: Image Received
# [INFO] [1760688300.535762797] [Image_Subscriber]: Image Received
# [INFO] [1760688300.592805846] [Image_Subscriber]: Image Received
# [INFO] [1760688300.622210370] [Image_Subscriber]: Image Received
# [INFO] [1760688300.633732854] [Image_Subscriber]: Image Received
# [INFO] [1760688300.694888961] [Image_Subscriber]: Image Received
# [INFO] [1760688300.707223320] [Image_Subscriber]: Image Received
# [INFO] [1760688300.731307735] [Image_Subscriber]: Image Received
# [INFO] [1760688300.789777584] [Image_Subscriber]: Image Received
# [INFO] [1760688300.818029219] [Image_Subscriber]: Image Received
# [INFO] [1760688300.845932138] [Image_Subscriber]: Image Received
# [INFO] [1760688300.895254078] [Image_Subscriber]: Image Received
# [INFO] [1760688300.923802362] [Image_Subscriber]: Image Received
# [INFO] [1760688300.951422545] [Image_Subscriber]: Image Received
# [INFO] [1760688301.002576048] [Image_Subscriber]: Image Received
# [INFO] [1760688301.032209129] [Image_Subscriber]: Image Received
# [INFO] [1760688301.067451622] [Image_Subscriber]: Closing stream window..
# [INFO] [1760688301.100485908] [Image_Subscriber]: Image Received
# [INFO] [1760688301.120407521] [Image_Subscriber]: Image Received
# [INFO] [1760688301.147100302] [Image_Subscriber]: Image Received
# [INFO] [1760688301.182983834] [Image_Subscriber]: Image Received
# [INFO] [1760688301.228692635] [Image_Subscriber]: Image Received
# [INFO] [1760688301.284131664] [Image_Subscriber]: Image Received
# [INFO] [1760688301.325444705] [Image_Subscriber]: Image Received
# [INFO] [1760688301.365491745] [Image_Subscriber]: Image Received
# [INFO] [1760688301.399931096] [Image_Subscriber]: Image Received
# [INFO] [1760688301.432582607] [Image_Subscriber]: Image Received
# [INFO] [1760688301.465789564] [Image_Subscriber]: Image Received
# [INFO] [1760688301.498709487] [Image_Subscriber]: Image Received
# [INFO] [1760688301.533809480] [Image_Subscriber]: Image Received
# [INFO] [1760688301.552081467] [Image_Subscriber]: Image Received
# [INFO] [1760688301.570739113] [Image_Subscriber]: Image Received
# [INFO] [1760688301.607722306] [Image_Subscriber]: Image Received
# [INFO] [1760688301.645369566] [Image_Subscriber]: Image Received
# [INFO] [1760688301.703480182] [Image_Subscriber]: Image Received
# [INFO] [1760688301.741519533] [Image_Subscriber]: Image Received
# [INFO] [1760688301.763907168] [Image_Subscriber]: Image Received
# [INFO] [1760688301.793922001] [Image_Subscriber]: Image Received
# [INFO] [1760688301.830027937] [Image_Subscriber]: Image Received
# [INFO] [1760688301.864044406] [Image_Subscriber]: Image Received
# [INFO] [1760688301.897430574] [Image_Subscriber]: Image Received
# [INFO] [1760688301.941081931] [Image_Subscriber]: Image Received
# [INFO] [1760688301.998555665] [Image_Subscriber]: Image Received
# [INFO] [1760688302.026785471] [Image_Subscriber]: Image Received
# [INFO] [1760688302.071511062] [Image_Subscriber]: Image Received
# [INFO] [1760688302.099261402] [Image_Subscriber]: Image Received
# [INFO] [1760688302.118779025] [Image_Subscriber]: Image Received
# [INFO] [1760688302.152761041] [Image_Subscriber]: Image Received
# [INFO] [1760688302.224026354] [Image_Subscriber]: Image Received
# [INFO] [1760688302.279343364] [Image_Subscriber]: Image Received
# [INFO] [1760688302.327276027] [Image_Subscriber]: Image Received
# [INFO] [1760688302.356726240] [Image_Subscriber]: Image Received
# [INFO] [1760688302.389373809] [Image_Subscriber]: Image Received
# [INFO] [1760688302.429889389] [Image_Subscriber]: Image Received
# [INFO] [1760688302.464096715] [Image_Subscriber]: Image Received
# [INFO] [1760688302.477734796] [Image_Subscriber]: Image Received
# [INFO] [1760688302.505681687] [Image_Subscriber]: Image Received
# [INFO] [1760688302.538329035] [Image_Subscriber]: Image Received
# [INFO] [1760688302.581649670] [Image_Subscriber]: Image Received
# [INFO] [1760688302.615623742] [Image_Subscriber]: Image Received
# [INFO] [1760688302.655428846] [Image_Subscriber]: Image Received
# [INFO] [1760688302.687055755] [Image_Subscriber]: Image Received
# [INFO] [1760688302.722326642] [Image_Subscriber]: Image Received
# [INFO] [1760688302.755189804] [Image_Subscriber]: Image Received
# [INFO] [1760688302.791738262] [Image_Subscriber]: Image Received
# [INFO] [1760688302.825151060] [Image_Subscriber]: Image Received
# [INFO] [1760688302.856516188] [Image_Subscriber]: Image Received
# [INFO] [1760688302.893034516] [Image_Subscriber]: Image Received
# [INFO] [1760688302.927699843] [Image_Subscriber]: Image Received
# [INFO] [1760688302.963737722] [Image_Subscriber]: Image Received
# [INFO] [1760688302.996436877] [Image_Subscriber]: Image Received
# [INFO] [1760688303.040038214] [Image_Subscriber]: Image Received
# [INFO] [1760688303.068206035] [Image_Subscriber]: Image Received
# [INFO] [1760688303.102677079] [Image_Subscriber]: Image Received
# [INFO] [1760688303.138700699] [Image_Subscriber]: Image Received
# [INFO] [1760688303.167351194] [Image_Subscriber]: Image Received
# [INFO] [1760688303.212661495] [Image_Subscriber]: Image Received
# [INFO] [1760688303.285439728] [Image_Subscriber]: Image Received
# [INFO] [1760688303.343897647] [Image_Subscriber]: Image Received
# [INFO] [1760688303.373662089] [Image_Subscriber]: Image Received
# [INFO] [1760688303.408642942] [Image_Subscriber]: Image Received
# [INFO] [1760688303.436289175] [Image_Subscriber]: Image Received
# [INFO] [1760688303.452918269] [Image_Subscriber]: Image Received
# [INFO] [1760688303.493411663] [Image_Subscriber]: Image Received
# [INFO] [1760688303.527210584] [Image_Subscriber]: Image Received
# [INFO] [1760688303.585614402] [Image_Subscriber]: Image Received
# [INFO] [1760688303.617230965] [Image_Subscriber]: Image Received
# [INFO] [1760688303.648207800] [Image_Subscriber]: Image Received
# [INFO] [1760688303.660235200] [Image_Subscriber]: Stopping the stream ...
# Failed to publish log message to rosout: publisher's context is invalid, at ./src/rcl/publisher.c:389
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4044/3890903897.py in <module>
#      81     image_subscriber = Get_Images()
# ---> 82     rclpy.spin(image_subscriber)
#      83
#
# /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/__init__.py in spin(node, executor)
#     225         while executor.context.ok():
# --> 226             executor.spin_once()
#     227     finally:
#
# /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py in spin_once(self, timeout_sec)
#     738     def spin_once(self, timeout_sec: float = None) -> None:
# --> 739         self._spin_once_impl(timeout_sec)
#     740
#
# /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py in _spin_once_impl(self, timeout_sec)
#     727         try:
# --> 728             handler, entity, node = self.wait_for_ready_callbacks(timeout_sec=timeout_sec)
#     729         except ShutdownException:
#
# /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py in wait_for_ready_callbacks(self, *args, **kwargs)
#     710             try:
# --> 711                 return next(self._cb_iter)
#     712             except StopIteration:
#
# /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py in _wait_for_ready_callbacks(self, timeout_sec, nodes, condition)
#     607                 # Wait for something to become ready
# --> 608                 wait_set.wait(timeout_nsec)
#     609                 if self._is_shutdown:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# RCLError                                  Traceback (most recent call last)
# /tmp/ipykernel_4044/3890903897.py in <module>
#      86     image_subscriber.stop_stream()
#      87     image_subscriber.destroy_node()
# ---> 88     rclpy.shutdown()
#
# /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/__init__.py in shutdown(context, uninstall_handlers)
#     128         If not, signal handlers won't be uninstalled.
#     129     """
# --> 130     _shutdown(context=context)
#     131     if (
#     132         uninstall_handlers or (
#
# /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/utilities.py in shutdown(context)
#      56     if context is None:
#      57         context = get_default_context(shutting_down=True)
# ---> 58     return context.shutdown()
#      59
#      60
#
# /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/context.py in shutdown(self)
#     100             raise RuntimeError('Context must be initialized before it can be shutdown')
#     101         with self.__context, self._lock:
# --> 102             self.__context.shutdown()
#     103             self._call_on_shutdown_callbacks()
#     104             self._logging_fini()
#
# RCLError: failed to shutdown: rcl_shutdown already called on the given context, at ./src/rcl/init.c:241
